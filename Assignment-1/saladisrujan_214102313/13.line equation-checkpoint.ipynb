# %%
import matplotlib.pyplot as plt  #importing matplotlib  
x=[-10,10]
y=[]
for i in x:  #getting values of y for every x
    j=3*i+2
    y.append(j)
plt.plot(x,y)   #plotting the line equation
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
